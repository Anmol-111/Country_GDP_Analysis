# %% [markdown]
# ## CASE STUDEY: COUNTRY GDP

# %%
import numpy as np
import pandas as pd

# %%
dataframe = pd.read_csv('countries of the world.csv', delimiter=',')

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             227 non-null    object
#  1   Region                              227 non-null    object
#  2   Population                          227 non-null    int64
#  3   Area (sq. mi.)                      227 non-null    int64
#  4   Pop. Density (per sq. mi.)          227 non-null    object
#  5   Coastline (coast/area ratio)        227 non-null    object
#  6   Net migration                       224 non-null    object
#  7   Infant mortality (per 1000 births)  224 non-null    object
#  8   GDP ($ per capita)                  226 non-null    float64
#  9   Literacy (%)                        209 non-null    object
#  10  Phones (per 1000)                   223 non-null    object
# ...

# %%
dataframe.dropna()
# Out:
#                 Country                               Region  Population  \
# 0          Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1              Albania   EASTERN EUROPE                          3581655
# 2              Algeria   NORTHERN AFRICA                        32930091
# 6             Anguilla               LATIN AMER. & CARIB           13477
# 7    Antigua & Barbuda               LATIN AMER. & CARIB           69108
# ..                  ...                                  ...         ...
# 218          Venezuela               LATIN AMER. & CARIB        25730435
# 219            Vietnam         ASIA (EX. NEAR EAST)             84402966
# 224              Yemen   NEAR EAST                              21456188
# 225             Zambia   SUB-SAHARAN AFRICA                     11502010
# 226           Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# ...

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             227 non-null    object
#  1   Region                              227 non-null    object
#  2   Population                          227 non-null    int64
#  3   Area (sq. mi.)                      227 non-null    int64
#  4   Pop. Density (per sq. mi.)          227 non-null    object
#  5   Coastline (coast/area ratio)        227 non-null    object
#  6   Net migration                       224 non-null    object
#  7   Infant mortality (per 1000 births)  224 non-null    object
#  8   GDP ($ per capita)                  226 non-null    float64
#  9   Literacy (%)                        209 non-null    object
#  10  Phones (per 1000)                   223 non-null    object
# ...

# %% [markdown]
# ### Convert column to numpy

# %%
country_name = np.array(dataframe['Country'].values)

# %%
country_name
# Out:
# array(['Afghanistan ', 'Albania ', 'Algeria ', 'American Samoa ',
#        'Andorra ', 'Angola ', 'Anguilla ', 'Antigua & Barbuda ',
#        'Argentina ', 'Armenia ', 'Aruba ', 'Australia ', 'Austria ',
#        'Azerbaijan ', 'Bahamas, The ', 'Bahrain ', 'Bangladesh ',
#        'Barbados ', 'Belarus ', 'Belgium ', 'Belize ', 'Benin ',
#        'Bermuda ', 'Bhutan ', 'Bolivia ', 'Bosnia & Herzegovina ',
#        'Botswana ', 'Brazil ', 'British Virgin Is. ', 'Brunei ',
#        'Bulgaria ', 'Burkina Faso ', 'Burma ', 'Burundi ', 'Cambodia ',
#        'Cameroon ', 'Canada ', 'Cape Verde ', 'Cayman Islands ',
#        'Central African Rep. ', 'Chad ', 'Chile ', 'China ', 'Colombia ',
#        'Comoros ', 'Congo, Dem. Rep. ', 'Congo, Repub. of the ',
#        'Cook Islands ', 'Costa Rica ', "Cote d'Ivoire ", 'Croatia ',
#        'Cuba ', 'Cyprus ', 'Czech Republic ', 'Denmark ', 'Djibouti ',
#        'Dominica ', 'Dominican Republic ', 'East Timor ', 'Ecuador ',
# ...

# %%
dataframe['GDP ($ per capita)'] = dataframe['GDP ($ per capita)'].fillna(0)

# %%
GDP = np.array(dataframe['GDP ($ per capita)'].values)

# %%
GDP
# Out:
# array([  700.,  4500.,  6000.,  8000., 19000.,  1900.,  8600., 11000.,
#        11200.,  3500., 28000., 29000., 30000.,  3400., 16700., 16900.,
#         1900., 15700.,  6100., 29100.,  4900.,  1100., 36000.,  1300.,
#         2400.,  6100.,  9000.,  7600., 16000., 18600.,  7600.,  1100.,
#         1800.,   600.,  1900.,  1800., 29800.,  1400., 35000.,  1100.,
#         1200.,  9900.,  5000.,  6300.,   700.,   700.,   700.,  5000.,
#         9100.,  1400., 10600.,  2900., 19200., 15700., 31100.,  1300.,
#         5400.,  6000.,   500.,  3300.,  4000.,  4800.,  2700.,   700.,
#        12300.,   700., 22000.,  5800., 27400., 27600.,  8300., 17500.,
#         5500.,  1700.,   600.,  2500., 27600.,  2200., 17500., 20000.,
#        20000.,  5000.,  8000., 21000.,  4100., 20000.,  2100.,   800.,
#         4000.,  1600.,  2600., 28800., 13900., 30900.,  2900.,  3200.,
#         7000.,  1500., 29600., 21000., 19800., 26700.,  3900., 28200.,
# ...

# %% [markdown]
# ### 1. Find and print the name of the country with the highest GDP.

# %%
print(country_name)
print(GDP)
# Out:
# ['Afghanistan ' 'Albania ' 'Algeria ' 'American Samoa ' 'Andorra '
#  'Angola ' 'Anguilla ' 'Antigua & Barbuda ' 'Argentina ' 'Armenia '
#  'Aruba ' 'Australia ' 'Austria ' 'Azerbaijan ' 'Bahamas, The ' 'Bahrain '
#  'Bangladesh ' 'Barbados ' 'Belarus ' 'Belgium ' 'Belize ' 'Benin '
#  'Bermuda ' 'Bhutan ' 'Bolivia ' 'Bosnia & Herzegovina ' 'Botswana '
#  'Brazil ' 'British Virgin Is. ' 'Brunei ' 'Bulgaria ' 'Burkina Faso '
#  'Burma ' 'Burundi ' 'Cambodia ' 'Cameroon ' 'Canada ' 'Cape Verde '
#  'Cayman Islands ' 'Central African Rep. ' 'Chad ' 'Chile ' 'China '
#  'Colombia ' 'Comoros ' 'Congo, Dem. Rep. ' 'Congo, Repub. of the '
#  'Cook Islands ' 'Costa Rica ' "Cote d'Ivoire " 'Croatia ' 'Cuba '
#  'Cyprus ' 'Czech Republic ' 'Denmark ' 'Djibouti ' 'Dominica '
#  'Dominican Republic ' 'East Timor ' 'Ecuador ' 'Egypt ' 'El Salvador '
#  'Equatorial Guinea ' 'Eritrea ' 'Estonia ' 'Ethiopia ' 'Faroe Islands '
#  'Fiji ' 'Finland ' 'France ' 'French Guiana ' 'French Polynesia '
# ...

# %%
max_gdp = GDP.argmax()

# %%
country_name_max_gdp = country_name[max_gdp]

# %%
country_name_max_gdp
# Out:
# 'Luxembourg '

# %% [markdown]
# ### 2. Find and print the name of the country with the lowest GDP.

# %%
min_gdp = GDP.argmin()

# %%
country_name_min_gdp = country_name[min_gdp]

# %%
country_name_min_gdp
# Out:
# 'Western Sahara '

# %% [markdown]
# ### 3. Print out text and input values iteratively.

# %%
for counter in range(len(country_name)):
    print("Country {}".format(country_name[counter]))
# Out:
# Country Afghanistan
# Country Albania
# Country Algeria
# Country American Samoa
# Country Andorra
# Country Angola
# Country Anguilla
# Country Antigua & Barbuda
# Country Argentina
# Country Armenia
# Country Aruba
# Country Australia
# Country Austria
# Country Azerbaijan
# Country Bahamas, The
# Country Bahrain
# Country Bangladesh
# Country Barbados
# Country Belarus
# Country Belgium
# Country Belize
# Country Benin
# Country Bermuda
# Country Bhutan
# Country Bolivia
# Country Bosnia & Herzegovina
# Country Botswana
# Country Brazil
# Country British Virgin Is.
# Country Brunei
# Country Bulgaria
# Country Burkina Faso
# Country Burma
# Country Burundi
# Country Cambodia
# Country Cameroon
# Country Canada
# Country Cape Verde
# Country Cayman Islands
# Country Central African Rep.
# Country Chad
# Country Chile
# Country China
# Country Colombia
# Country Comoros
# Country Congo, Dem. Rep.
# Country Congo, Repub. of the
# Country Cook Islands
# Country Costa Rica
# ...

# %%
for counter in range(len(country_name)):
    print("gdp per capita is {}".format(GDP[counter]))
# Out:
# gdp per capita is 700.0
# gdp per capita is 4500.0
# gdp per capita is 6000.0
# gdp per capita is 8000.0
# gdp per capita is 19000.0
# gdp per capita is 1900.0
# gdp per capita is 8600.0
# gdp per capita is 11000.0
# gdp per capita is 11200.0
# gdp per capita is 3500.0
# gdp per capita is 28000.0
# gdp per capita is 29000.0
# gdp per capita is 30000.0
# gdp per capita is 3400.0
# gdp per capita is 16700.0
# gdp per capita is 16900.0
# gdp per capita is 1900.0
# gdp per capita is 15700.0
# gdp per capita is 6100.0
# gdp per capita is 29100.0
# gdp per capita is 4900.0
# gdp per capita is 1100.0
# gdp per capita is 36000.0
# gdp per capita is 1300.0
# gdp per capita is 2400.0
# gdp per capita is 6100.0
# gdp per capita is 9000.0
# gdp per capita is 7600.0
# gdp per capita is 16000.0
# gdp per capita is 18600.0
# gdp per capita is 7600.0
# gdp per capita is 1100.0
# gdp per capita is 1800.0
# gdp per capita is 600.0
# gdp per capita is 1900.0
# gdp per capita is 1800.0
# ...

# %% [markdown]
# ### 4. Print out the entire list of the countries with their GDPs.

# %%
for counter in range(len(country_name)):
    print("Country {} gdp per capita is {}".format(country_name[counter],GDP[counter]))
# Out:
# Country Afghanistan  gdp per capita is 700.0
# Country Albania  gdp per capita is 4500.0
# Country Algeria  gdp per capita is 6000.0
# Country American Samoa  gdp per capita is 8000.0
# Country Andorra  gdp per capita is 19000.0
# Country Angola  gdp per capita is 1900.0
# Country Anguilla  gdp per capita is 8600.0
# Country Antigua & Barbuda  gdp per capita is 11000.0
# Country Argentina  gdp per capita is 11200.0
# Country Armenia  gdp per capita is 3500.0
# Country Aruba  gdp per capita is 28000.0
# Country Australia  gdp per capita is 29000.0
# Country Austria  gdp per capita is 30000.0
# Country Azerbaijan  gdp per capita is 3400.0
# Country Bahamas, The  gdp per capita is 16700.0
# Country Bahrain  gdp per capita is 16900.0
# Country Bangladesh  gdp per capita is 1900.0
# Country Barbados  gdp per capita is 15700.0
# Country Belarus  gdp per capita is 6100.0
# Country Belgium  gdp per capita is 29100.0
# Country Belize  gdp per capita is 4900.0
# ...

# %% [markdown]
# ### 5. Print the highest GDP value, lowest GDP value, mean GDP value, standardized GDP value, and the sum of all the GDPs.

# %%
max_GDP_per_capita_value = GDP.max()

# %%
print("Highest GDP value: ", max_GDP_per_capita_value)
# Out:
# Highest GDP value:  55100.0

# %%
min_GDP_per_capita_value = GDP.min()

# %%
print("Lowest GDP value: ", min_GDP_per_capita_value)
# Out:
# Lowest GDP value:  0.0

# %%
standard_GDP_value = GDP.std()

# %%
print("Standard GDP Value: ", standard_GDP_value)
# Out:
# Standard GDP Value:  10025.330394056082

# %%
print("Sum of all GDP's :",sum_GDP)
# Out:
# Sum of all GDP's : 2189900.0
